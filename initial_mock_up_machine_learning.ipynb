# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder

# %%
file_path = 'Police_Department_Incidents_-_Previous_Year__2016_.csv'
crime_df = pd.read_csv(file_path)
crime_df
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
# Exploratory data analysis
# Generate our categorical variable list
categories = crime_df.dtypes[crime_df.dtypes == "object"].index.tolist()

# Check the number of unique values in each column
crime_df[categories].nunique()
# Out:
# Category         39
# Descript        726
# DayOfWeek         7
# Date            366
# Time           1439
# PdDistrict       10
# Resolution       14
# Address       16130
# Location      19386
# dtype: int64

# %%
# Look at Category column
category_counts = crime_df.Category.value_counts()
category_counts
# Out:
# LARCENY/THEFT                  40409
# OTHER OFFENSES                 19599
# NON-CRIMINAL                   17866
# ASSAULT                        13577
# VANDALISM                       8589
# VEHICLE THEFT                   6419
# WARRANTS                        5914
# BURGLARY                        5802
# SUSPICIOUS OCC                  5782
# MISSING PERSON                  4338
# DRUG/NARCOTIC                   4243
# ROBBERY                         3299
# FRAUD                           2635
# SECONDARY CODES                 1841
# TRESPASS                        1812
# WEAPON LAWS                     1658
# SEX OFFENSES, FORCIBLE           940
# STOLEN PROPERTY                  882
# RECOVERED VEHICLE                736
# DISORDERLY CONDUCT               658
# PROSTITUTION                     641
# FORGERY/COUNTERFEITING           619
# DRUNKENNESS                      465
# DRIVING UNDER THE INFLUENCE      378
# ARSON                            286
# ...

# %%
# Replace categories with less than 1000 with 'other'
replace_cat = list(category_counts[category_counts < 1000].index)

for cat in replace_cat:
    crime_df.Category = crime_df.Category.replace(cat, 'Other')

crime_df.Category.value_counts()
# Out:
# LARCENY/THEFT      40409
# OTHER OFFENSES     19599
# NON-CRIMINAL       17866
# ASSAULT            13577
# VANDALISM           8589
# Other               6717
# VEHICLE THEFT       6419
# WARRANTS            5914
# BURGLARY            5802
# SUSPICIOUS OCC      5782
# MISSING PERSON      4338
# DRUG/NARCOTIC       4243
# ROBBERY             3299
# FRAUD               2635
# SECONDARY CODES     1841
# TRESPASS            1812
# WEAPON LAWS         1658
# Name: Category, dtype: int64

# %%
# Look at Pd District column
pdDistricts = crime_df.PdDistrict.value_counts()
pdDistricts
# Out:
# SOUTHERN      28445
# NORTHERN      20100
# MISSION       19503
# CENTRAL       17666
# BAYVIEW       14303
# INGLESIDE     11594
# TARAVAL       11325
# TENDERLOIN     9942
# RICHMOND       8922
# PARK           8699
# Name: PdDistrict, dtype: int64

# %%
resolutionCounts = crime_df.Resolution.value_counts()
resolutionCounts
# Out:
# NONE                                      107780
# ARREST, BOOKED                             39416
# UNFOUNDED                                   1608
# JUVENILE BOOKED                             1056
# EXCEPTIONAL CLEARANCE                        371
# ARREST, CITED                                144
# CLEARED-CONTACT JUVENILE FOR MORE INFO        58
# NOT PROSECUTED                                22
# LOCATED                                       20
# PSYCHOPATHIC CASE                             17
# JUVENILE CITED                                 3
# JUVENILE DIVERTED                              2
# COMPLAINANT REFUSES TO PROSECUTE               2
# PROSECUTED BY OUTSIDE AGENCY                   1
# Name: Resolution, dtype: int64

# %%
# Drop rows that have anything other than NONE or ARREST, BOOKED for the resolution column
to_drop = ['UNFOUNDED', 'JUVENILE BOOKED', 'EXCEPTIONAL CLEARANCE', 'ARREST, CITED', 'CLEARED-CONTACT JUVENILE FOR MORE INFO', 'NOT PROSECUTED', 'LOCATED', 'PSYCHOPATHIC CASE', 'JUVENILE CITED', 'COMPLAINANT REFUSES TO PROSECUTE', 'JUVENILE DIVERTED', 'PROSECUTED BY OUTSIDE AGENCY']
clean_df = crime_df[~crime_df['Resolution'].isin(to_drop)]
clean_df
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
resolutionCounts_2 = clean_df.Resolution.value_counts()
resolutionCounts_2
# Out:
# NONE              107780
# ARREST, BOOKED     39416
# Name: Resolution, dtype: int64

# %%
# split into target and features
y = clean_df['Resolution']
X = clean_df.drop(columns=["Resolution", "IncidntNum", "PdId", "Location", "X", "Y", "Address", "Descript", "Date", "Time"])

# %%
X_encoded = pd.get_dummies(X)
X_encoded
# Out:
#         Category_ASSAULT  Category_BURGLARY  Category_DRUG/NARCOTIC  \
# 0                      0                  0                       0
# 1                      0                  0                       0
# 2                      0                  0                       0
# 3                      0                  0                       0
# 4                      0                  0                       0
# ...                  ...                ...                     ...
# 150495                 1                  0                       0
# 150496                 0                  0                       0
# 150497                 0                  0                       0
# 150498                 0                  0                       0
# 150499                 0                  0                       0
#
#         Category_FRAUD  Category_LARCENY/THEFT  Category_MISSING PERSON  \
# 0                    0                       0                        0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=1, stratify=y)
X_train.shape
# Out:
# (110397, 34)

# %%
from sklearn.svm import SVC
model = SVC(kernel='linear')

# %%
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8287725209924183
